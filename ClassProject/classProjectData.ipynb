# %%
import pandas as pd
import numpy as np

pd.read_csv("h08.csv")

df = pd.read_csv("h08.csv", header=[0,1])
print(df)
# Out:
#     Table with row headers in column A and column headers in rows 8 through 9 and 63 through 64  \
#                                       Table H-8. Median Household Income by State: 1984 to 2021
# 0    Information on confidentiality protection, sam...
# 1    Footnotes are available at <www.census.gov/top...
# 2    Source: U.S. Census Bureau, Current Population...
# 3    (Households as of March of the following year....
# 4                                      Current Dollars
# ..                                                 ...
# 109                                           Virginia
# 110                                         Washington
# 111                                      West Virginia
# 112                                          Wisconsin
# 113                                            Wyoming
#
#     Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#     Unnamed: 1_level_1 Unnamed: 2_level_1 Unnamed: 3_level_1
# ...
